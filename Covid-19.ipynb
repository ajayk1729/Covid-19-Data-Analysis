# %%
#import numpy for mathematical operations
#import pandas for reading csv file, data visualization
import numpy as np
import pandas as pd

# %%
import os

# %%
#files in my directory to visualize data
for dirname, _, filenames in os.walk('/Python/Kaggle'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /Python/Kaggle\country_wise_latest.csv
# /Python/Kaggle\covid_19_clean_complete.csv
# /Python/Kaggle\day_wise.csv
# /Python/Kaggle\full_grouped.csv
# /Python/Kaggle\usa_county_wise.csv
# /Python/Kaggle\worldometer_data.csv

# %%
#importing matplotlib, seaborn for graph visualization
import plotly.express as px
import seaborn as sns
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/Python/Kaggle/country_wise_latest.csv') 
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
#coping data to df_original
df_original=df.copy()
df_original
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
#check data from row number 145 to 169
subset1 = df.iloc[145:170]
subset1
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 145   Saudi Arabia     268934    2760     222936   43238       1993
# 146        Senegal       9764     194       6477    3093         83
# 147         Serbia      24141     543          0   23598        411
# 148     Seychelles        114       0         39      75          0
# 149   Sierra Leone       1783      66       1317     400          0
# 150      Singapore      50838      27      45692    5119        469
# 151       Slovakia       2181      28       1616     537          2
# 152       Slovenia       2087     116       1733     238          5
# 153        Somalia       3196      93       1543    1560         18
# 154   South Africa     452529    7067     274925  170537       7096
# 155    South Korea      14203     300      13007     896         28
# 156    South Sudan       2305      46       1175    1084         43
# 157          Spain     272421   28432     150376   93613          0
# ...

# %%
#check first 10 data
df_original.head(10)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %%
#check last 10 rows
df_original.tail(10)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 177      United Kingdom     301708   45844       1437  254427        688
# 178             Uruguay       1202      35        951     216         10
# 179          Uzbekistan      21209     121      11674    9414        678
# 180           Venezuela      15988     146       9959    5883        525
# 181             Vietnam        431       0        365      66         11
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 177           7              3               15.19                   0.48
# ...

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df.nunique() #checking unique
# Out:
# Country/Region            187
# Confirmed                 184
# Deaths                    150
# Recovered                 178
# Active                    173
# New cases                 122
# New deaths                 38
# New recovered             103
# Deaths / 100 Cases        145
# Recovered / 100 Cases     177
# Deaths / 100 Recovered    155
# Confirmed last week       183
# 1 week change             162
# 1 week % increase         169
# WHO Region                  6
# dtype: int64

# %%
df.dtypes[df.dtypes == 'int64'] #checking column has integer data
# Out:
# Confirmed              int64
# Deaths                 int64
# Recovered              int64
# Active                 int64
# New cases              int64
# New deaths             int64
# New recovered          int64
# Confirmed last week    int64
# 1 week change          int64
# dtype: object

# %%
df.isnull().values.any() #checking if there is null values or not
# Out:
# False

# %%
df.isnull().any()  #checking if column has there is null values or not
# Out:
# Country/Region            False
# Confirmed                 False
# Deaths                    False
# Recovered                 False
# Active                    False
# New cases                 False
# New deaths                False
# New recovered             False
# Deaths / 100 Cases        False
# Recovered / 100 Cases     False
# Deaths / 100 Recovered    False
# Confirmed last week       False
# 1 week change             False
# 1 week % increase         False
# WHO Region                False
# dtype: bool

# %%
df.isnull().sum() ## summation of null values
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
#Converting the column data_type

#1.Replace non-finite values with 0,

#2.Convert to integer data type in case of string values so that we can easily visulaize
df['Deaths / 100 Recovered']=df['Deaths / 100 Recovered'].replace([np.inf, np.nan], 0).astype(int)
df['Deaths / 100 Recovered']
# Out:
# 0       3
# 1       5
# 2       6
# 3       6
# 4      16
#        ..
# 182     2
# 183    12
# 184    57
# 185     4
# 186     6
# Name: Deaths / 100 Recovered, Length: 187, dtype: int32

# %%
#checking data after modifying the data
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
#to check if there is changes done by above processing or not
changes = df_original['Deaths / 100 Recovered'] != df['Deaths / 100 Recovered']
if changes.any():
    print("Changes have been made to the column.")
else:
    print("No changes have been made to the column.")
# Out:
# Changes have been made to the column.

# %%
#compare US data and India data (confirmed and recovered)
df_compare=df[df['Country/Region'].isin(['US','India'])][['Country/Region','Confirmed','Recovered']]
df_compare = df_compare.set_index('Country/Region')
df_compare
# Out:
#                 Confirmed  Recovered
# Country/Region
# India             1480073     951166
# US                4290259    1325804

# %%
df_compare.plot.bar()
# Out:
# <Axes: xlabel='Country/Region'>

# %%
df_new = df[['Country/Region', 'New cases', 'New deaths', 'New recovered']]
df_new
# Out:
#          Country/Region  New cases  New deaths  New recovered
# 0           Afghanistan        106          10             18
# 1               Albania        117           6             63
# 2               Algeria        616           8            749
# 3               Andorra         10           0              0
# 4                Angola         18           1              0
# ..                  ...        ...         ...            ...
# 182  West Bank and Gaza        152           2              0
# 183      Western Sahara          0           0              0
# 184               Yemen         10           4             36
# 185              Zambia         71           1            465
# 186            Zimbabwe        192           2             24
#
# [187 rows x 4 columns]

# %%
Country_based_new_case = df_new.groupby('Country/Region')['New cases'].sum()
Country_based_new_case
# Out:
# Country/Region
# Afghanistan           106
# Albania               117
# Algeria               616
# Andorra                10
# Angola                 18
#                      ...
# West Bank and Gaza    152
# Western Sahara          0
# Yemen                  10
# Zambia                 71
# Zimbabwe              192
# Name: New cases, Length: 187, dtype: int64

# %%
#Top 10 countries
Top_10_countries = Country_based_new_case.sort_values(ascending=False).head(10)
plt.bar(Top_10_countries.index, Top_10_countries.values)
plt.xlabel('Country')
plt.ylabel('New cases')
plt.title('Top 10 Countries by New cases')
plt.xticks(rotation=45)
plt.show()

# %%
#Plot between confirmed and Recovered
sns.relplot(x="Confirmed",y="Recovered",data=df)

# %%
#Plot between confirmed and Recovered with line
sns.relplot(x="Confirmed",y="Recovered",kind="line",data=df)
